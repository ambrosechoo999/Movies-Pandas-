# %% [markdown]
# <a href="https://colab.research.google.com/github/ambrosechoo999/Movies-Pandas-/blob/main/Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Personal Projects/data/Movies.csv")

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# # What movies by James Gunn recieved a meta score above 60.0?

# %%
df_meta = df[(df['Metascore'] > 60) & (df['Director']=='James Gunn')]
df_meta
# Out:
#      Rank                    Title                    Genre  \
# 0       1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
# 908   909                  Slither     Comedy,Horror,Sci-Fi
#
#                                            Description    Director  \
# 0    A group of intergalactic criminals are forced ...  James Gunn
# 908  A small town is taken over by an alien plague,...  James Gunn
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 908  Nathan Fillion, Elizabeth Banks, Michael Rooke...  2006
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 908                 95     6.5   64351                7.77       69.0

# %% [markdown]
# # What movie was Chris Pratt in and which had the highest votes?

# %%
#Movie that Chris Pratt is in
chris_pratt =df[df['Actors'].str.contains('Chris Pratt')]
chris_pratt
# Out:
#      Rank                    Title                       Genre  \
# 0       1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 9      10               Passengers     Adventure,Drama,Romance
# 38     39    The Magnificent Seven    Action,Adventure,Western
# 85     86           Jurassic World     Action,Adventure,Sci-Fi
# 384   385           The Lego Movie  Animation,Action,Adventure
# 406   407         Zero Dark Thirty      Drama,History,Thriller
# 696   697                 10 Years        Comedy,Drama,Romance
#
#                                            Description         Director  \
# 0    A group of intergalactic criminals are forced ...       James Gunn
# 9    A spacecraft traveling to a distant colony pla...    Morten Tyldum
# 38   Seven gunmen in the old west gradually come to...    Antoine Fuqua
# 85   A new theme park, built on the original site o...  Colin Trevorrow
# 384  An ordinary Lego construction worker, thought ...        Phil Lord
# ...

# %%
#Highest voted Chris Pratt Movies
i = chris_pratt['Votes'].idxmax() #get the index of the maximum voted Chris Pratt Movies
chris_pratt_max = chris_pratt['Votes'].max() # Get the maximum number of votes for the highest Chriss Pratt Movies
df['Title'][i],chris_pratt_max
# Out:
# ('Guardians of the Galaxy', 757074)
